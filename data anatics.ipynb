# %%
Name : Vrushali ponkia(n01530336)
       Janki Patel(n01533282)

# %%
Problem statement : Analyze the chances of a student getting admission in a university.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('~/Downloads/Data for admission in the university.csv')

# %%
print('First five rows')
df.head()
# Out:
# First five rows
#    Serial No.       University Name        Location  GRE Score  TOEFL Score  \
# 0           1  Utah State University  Princeton, NJ        337          118
# 1           2   Princeton University  Cambridge, MA        324          107
# 2           3     Harvard University    Chicago, IL        316          104
# 3           4  University of Chicago  New Haven, CT        322          110
# 4           5        Yale University   New York, NY        314          103
#
#    University Rating  SOP  LOR   CGPA  Research  Chance of Admit  Scholarship
# 0                  4  4.5   4.5  9.65         1              0.92         Yes
# 1                  4  4.0   4.5  8.87         1              0.76          No
# 2                  3  3.0   3.5  8.00         1              0.72          No
# 3                  3  3.5   2.5  8.67         1              0.80         Yes
# 4                  2  2.0   3.0  8.21         0              0.65          No

# %%
print('Column names are')
df.columns #columns name
# Out:
# Column names are
# Index(['Serial No.', 'University Name ', 'Location', 'GRE Score',
#        'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research',
#        'Chance of Admit ', 'Scholarship'],
#       dtype='object')

# %%
#Dimensions of the data frame with shape
print('The dimensions of the dataset')
dimensions = df.shape
dimensions
# Out:
# The dimensions of the dataset
# (231, 12)

# %%
print('Data type of columns')
df.dtypes #Data type of each column
# Out:
# Data type of columns
# Serial No.             int64
# University Name       object
# Location              object
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# Scholarship           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         231 non-null    int64
#  1   University Name    231 non-null    object
#  2   Location           231 non-null    object
#  3   GRE Score          231 non-null    int64
#  4   TOEFL Score        231 non-null    int64
#  5   University Rating  231 non-null    int64
#  6   SOP                231 non-null    float64
#  7   LOR                231 non-null    float64
#  8   CGPA               231 non-null    float64
#  9   Research           231 non-null    int64
#  10  Chance of Admit    231 non-null    float64
#  11  Scholarship        231 non-null    object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 21.8+ KB

# %%
print('Total null values in each column')
df.isnull().sum() #Gives sum of null values in individual column
#Dataset doesn't have any missing values
# Out:
# Total null values in each column
# Serial No.           0
# University Name      0
# Location             0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# Scholarship          0
# dtype: int64

# %%
print('Total duplicate values')
df.duplicated().sum() #Gives the number of duplicate values
#Dataset doesn't have a duplicate value
# Out:
# Total duplicate values
# 0

# %%
#Univariate

# %%
print('Description of dataset')
df.describe()
#Here we can see the univariante analysis
#That is mean and standard deviation of each column
# Out:
# Description of dataset
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  231.000000  231.000000   231.000000         231.000000  231.000000
# mean   116.000000  317.649351   108.341991           3.272727    3.567100
# std     66.828138   11.829329     6.084186           1.164359    0.957147
# min      1.000000  290.000000    93.000000           1.000000    1.000000
# 25%     58.500000  309.500000   104.000000           2.000000    3.000000
# 50%    116.000000  318.000000   109.000000           3.000000    3.500000
# 75%    173.500000  326.000000   112.000000           4.000000    4.500000
# max    231.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  231.000000  231.000000  231.000000        231.000000
# mean     3.558442    8.642987    0.562771          0.727835
# std      0.863413    0.620506    0.497121          0.152311
# min      1.500000    6.800000    0.000000          0.340000
# 25%      3.000000    8.200000    0.000000          0.640000
# 50%      3.500000    8.640000    1.000000          0.730000
# 75%      4.000000    9.105000    1.000000          0.860000
# max      5.000000    9.920000    1.000000          0.970000

# %%
print('No skew that means mean is equivalent to median')
print('It is unimodal becuase it has only one peak')
print('mode is 324, median is 318 and mean is 316')
print('There are universities with min of 290 GRE score and max of 340 so student must have min of 290 GRE score to get into any university')
sns.histplot(x='GRE Score', data=df, kde=True, color='purple');
#histogram and Kernel Density Estimate
#univariate analysis on Numerical variables using the histogram function
# Out:
# No skew that means mean is equivalent to median
# It is unimodal becuase it has only one peak
# mode is 324, median is 318 and mean is 316
# There are universities with min of 290 GRE score and max of 340 so student must have min of 290 GRE score to get into any university

# %%
print('mode is 110, median is 107 and mean is 107.41')
print('Unimodal and symmetric distribution')
df['TOEFL Score'].hist()
# Out:
# mode is 110, median is 107 and mean is 107.41
# Unimodal and symmetric distribution
# <AxesSubplot:>

# %%
print('the minimum = 92, lower quartile = 103, median = 107, upper quartile = 112 and maximum = 120')
print('Universities min requirement in TOEFL is 92 and max is 120 so a student should have atleast 92 score')
sns.boxplot(x=df['TOEFL Score'])
# Out:
# the minimum = 92, lower quartile = 103, median = 107, upper quartile = 112 and maximum = 120
# Universities min requirement in TOEFL is 92 and max is 120 so a student should have atleast 92 score
# <AxesSubplot:xlabel='TOEFL Score'>

# %%
print('University with 3 star rating is more')
sns.countplot(df['University Rating']) #Univariate analysis of categorical data using the countplot function
# Out:
# University with 3 star rating is more
# C:\Users\ponki\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='University Rating', ylabel='count'>

# %%
x = df['SOP'].value_counts()
print('35% ofstudent has SOP rank of 3.5 and 4')
plt.pie(x.values, labels=x.index, autopct='%1.1f%%')
plt.show()
# Out:
# 35% ofstudent has SOP rank of 3.5 and 4

# %%
print('median is 8.61, mean is 8.59 and mode is 8')
print('no skewed and perfectly symmetric')
sns.histplot(x='CGPA', data=df, kde=True, color='red');
# Out:
# median is 8.61, mean is 8.59 and mode is 8
# no skewed and perfectly symmetric

# %%
print('84% of university do not require reserach work while taking admission and therefore it does not play a major role while taking admission.')
sns.countplot(x = df['Research'], palette=['#432371',"#FAAE7B"]);
# Out:
# 84% of university do not require reserach work while taking admission and therefore it does not play a major role while taking admission.

# %%
#Bivariate

# %%
new_df = df.drop(['Serial No.'], axis = 1)
new_df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
print('A positive linear relationship exists for below columns')
print('Chance of Admit and GRE Score: 0.802610')
print('Chance of Admit and TOEFL Score: 0.791594')
print('Chance of Admit and CGPA: 0.873289')
print('correlation matrix')
new_df.corr()
# Out:
# A positive linear relationship exists for below columns
# Chance of Admit and GRE Score: 0.802610
# Chance of Admit and TOEFL Score: 0.791594
# Chance of Admit and CGPA: 0.873289
# correlation matrix
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.567721  0.828417  0.489858          0.791594
# University Rating  0.660123  0.746479  0.447783          0.711250
# SOP                0.729593  0.718144  0.444029          0.675732
# LOR                1.000000  0.670211  0.396859          0.669889
# CGPA               0.670211  1.000000  0.521654          0.873289
# Research           0.396859  0.521654  1.000000          0.553202
# Chance of Admit    0.669889  0.873289  0.553202          1.000000

# %%
print('Box plot')
print('If GRE score is high, SOP will be stronger')
sns.boxplot(data=df, x='SOP', y='GRE Score')
# Out:
# Box plot
# If GRE score is high, SOP will be stronger
# <AxesSubplot:xlabel='SOP', ylabel='GRE Score'>

# %%
print('box plot')
print('If TOEFL score is high, SOP will be stronger')
sns.boxplot(data=df, x='SOP', y='TOEFL Score')
# Out:
# box plot
# If TOEFL score is high, SOP will be stronger
# <AxesSubplot:xlabel='SOP', ylabel='TOEFL Score'>

# %%
print('box plot')
print('If CGPA is high, SOP will be stronger')
sns.boxplot(data=df, x='SOP', y='CGPA')
# Out:
# box plot
# If CGPA is high, SOP will be stronger
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %%
x = df['University Rating']
y = df['SOP']
plt.xlabel('University Rating')
plt.ylabel('SOP')
plt.title('Relationship between SOP and university rating')
plt.bar(x,y)
print('If students SOP is strong then chance of getting in high rated university is more and that is 3, 4 and 5 star')
# Out:
# If students SOP is strong then chance of getting in high rated university is more and that is 3, 4 and 5 star

# %%
#multivariate

# %%
sns.pairplot(new_df[['GRE Score', 'TOEFL Score', 'CGPA','Chance of Admit ']])

# %%
print('Relation between Chance of Admit and GRE Score, TOEFL Score, CGPA: direction is positive, form is linear and strength is perfectly strong with some outliers')
sns.pairplot(new_df)
# Out:
# Relation between Chance of Admit and GRE Score, TOEFL Score, CGPA: direction is positive, form is linear and strength is perfectly strong with some outliers

# %%
print('A positive correlation exists for below columns')
print('Chance of Admit and GRE Score: 0.8')
print('Chance of Admit and TOEFL Score: 0.79')
print('Chance of Admit and CGPA: 0.87')
plt.figure(figsize = (5, 4))
sns.heatmap(new_df.corr(), annot = True)
# Out:
# A positive correlation exists for below columns
# Chance of Admit and GRE Score: 0.8
# Chance of Admit and TOEFL Score: 0.79
# Chance of Admit and CGPA: 0.87
# <AxesSubplot:>

# %%
#multi linear regression model

# %%
x = new_df[['TOEFL Score','CGPA','University Rating','GRE Score','Research']]
y = new_df['Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
# create a Linear Regression
lm = LinearRegression()

# %%
# fit the model
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# predict the model for test 
predictions = lm.predict(X_test)

# %%
# Feature scaling (Bringing whole data into a single form)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(X_train)
x_test = sc.transform(X_test)

# %%
print('Comparing actual and predicted values')
print('Predicted values are almost similar to actual values')
np.column_stack((predictions, y_test))
# Out:
# Comparing actual and predicted values
# Predicted values are almost similar to actual values
# array([[0.51485397, 0.52      ],
#        [0.61129223, 0.53      ],
#        [0.63594783, 0.72      ],
#        [0.65335865, 0.71      ],
#        [0.68146585, 0.78      ],
#        [0.70002145, 0.72      ],
#        [0.80082748, 0.79      ],
#        [0.4688025 , 0.47      ],
#        [0.85148124, 0.88      ],
#        [0.81536934, 0.78      ],
#        [0.79041782, 0.76      ],
#        [0.70094248, 0.75      ],
#        [0.88687973, 0.89      ],
#        [0.99604721, 0.97      ],
#        [0.57187658, 0.39      ],
#        [0.74480578, 0.75      ],
#        [0.69562195, 0.65      ],
#        [0.67344323, 0.7       ],
#        [0.50556152, 0.51      ],
#        [0.65927406, 0.62      ],
#        [0.5561352 , 0.58      ],
#        [0.66882802, 0.67      ],
#        [0.75702776, 0.78      ],
#        [0.602132  , 0.64      ],
#        [0.45993885, 0.57      ],
#        [0.81775436, 0.74      ],
#        [0.75452465, 0.78      ],
#        [0.69180683, 0.74      ],
#        [0.51218616, 0.57      ],
#        [0.82044696, 0.79      ],
#        [0.7206192 , 0.71      ],
#        [0.69097011, 0.59      ],
#        [0.56203572, 0.5       ],
#        [0.88754006, 0.93      ],
#        [0.50761741, 0.6       ],
#        [0.57384499, 0.57      ],
#        [0.66235046, 0.71      ],
#        [0.5747079 , 0.58      ],
#        [0.7207328 , 0.71      ],
#        [0.72399811, 0.77      ],
#        [0.61213307, 0.68      ],
#        [0.85771424, 0.87      ],
#        [0.89356794, 0.9       ],
#        [0.76935606, 0.74      ],
#        [0.71229419, 0.75      ],
#        [0.94456732, 0.96      ],
#        [0.63144946, 0.65      ],
#        [0.74044878, 0.77      ],
#        [0.55915866, 0.56      ],
#        [0.71436895, 0.72      ],
#        [0.61292256, 0.63      ],
#        [0.91116519, 0.93      ],
#        [0.79748857, 0.85      ],
#        [0.5356283 , 0.54      ],
#        [0.74122355, 0.73      ],
#        [0.77856102, 0.7       ],
#        [0.75341842, 0.72      ],
#        [0.59158361, 0.56      ],
#        [0.63176977, 0.65      ],
#        [0.53789991, 0.38      ],
#        [0.52576051, 0.49      ],
#        [0.68945999, 0.74      ],
#        [0.55002551, 0.64      ],
#        [0.53149611, 0.38      ],
#        [0.72321366, 0.72      ],
#        [0.58476459, 0.64      ],
#        [0.66826587, 0.76      ],
#        [0.63419662, 0.71      ],
#        [0.52999184, 0.45      ],
#        [0.67162991, 0.68      ],
#        [0.47780811, 0.53      ],
#        [0.80493025, 0.55      ],
#        [0.77662278, 0.82      ],
#        [0.75267646, 0.63      ],
#        [0.66657271, 0.54      ],
#        [0.97112371, 0.96      ],
#        [0.64150038, 0.62      ],
#        [0.8709019 , 0.9       ],
#        [0.66693624, 0.62      ],
#        [0.65075941, 0.64      ],
#        [0.65494395, 0.65      ],
#        [0.81799694, 0.8       ],
#        [0.51196061, 0.46      ],
#        [0.89486814, 0.91      ],
#        [0.85826023, 0.89      ],
#        [0.70996696, 0.73      ],
#        [0.68663842, 0.72      ],
#        [0.63352908, 0.73      ],
#        [0.78614083, 0.8       ],
#        [0.56868319, 0.7       ],
#        [0.6640305 , 0.72      ],
#        [0.5841174 , 0.65      ],
#        [0.86233357, 0.78      ],
#        [0.87785923, 0.9       ],
#        [0.51518343, 0.59      ],
#        [0.63031851, 0.65      ],
#        [0.53177223, 0.64      ],
#        [0.82133997, 0.76      ],
#        [0.63441407, 0.69      ],
#        [0.75758255, 0.52      ],
#        [0.57243225, 0.48      ],
#        [0.59055831, 0.42      ],
#        [0.71577628, 0.68      ],
#        [0.7312216 , 0.45      ],
#        [0.62329113, 0.67      ],
#        [0.84481081, 0.78      ],
#        [0.4640206 , 0.47      ],
#        [0.82388292, 0.84      ],
#        [0.93758823, 0.93      ],
#        [0.84748778, 0.85      ],
#        [0.72828319, 0.66      ],
#        [0.68705099, 0.7       ],
#        [0.6357117 , 0.64      ],
#        [0.77267025, 0.8       ],
#        [0.98707102, 0.97      ],
#        [0.74352121, 0.71      ],
#        [0.64484003, 0.72      ],
#        [0.66933219, 0.73      ],
#        [0.83188763, 0.83      ],
#        [0.70411545, 0.73      ],
#        [0.88158142, 0.86      ],
#        [0.83922074, 0.83      ],
#        [0.7377465 , 0.84      ],
#        [0.85319468, 0.87      ],
#        [0.65317313, 0.49      ],
#        [0.69728819, 0.74      ],
#        [0.85569257, 0.9       ],
#        [0.92159586, 0.91      ],
#        [0.63350792, 0.71      ],
#        [0.81422688, 0.84      ],
#        [0.95619945, 0.94      ],
#        [0.67321445, 0.7       ],
#        [0.90385738, 0.9       ],
#        [0.62617804, 0.64      ],
#        [0.65268202, 0.72      ],
#        [0.47771334, 0.47      ],
#        [0.49902775, 0.44      ],
#        [0.68221211, 0.57      ],
#        [0.69539244, 0.74      ],
#        [0.70101359, 0.71      ],
#        [0.59828009, 0.48      ],
#        [0.768427  , 0.82      ],
#        [0.66450704, 0.69      ],
#        [0.68183519, 0.71      ],
#        [0.89709402, 0.89      ],
#        [0.72289088, 0.78      ],
#        [0.84293466, 0.82      ],
#        [0.80062059, 0.8       ],
#        [0.6176169 , 0.61      ],
#        [0.71083235, 0.76      ],
#        [0.72791138, 0.71      ],
#        [0.49880133, 0.54      ],
#        [0.76396284, 0.79      ],
#        [0.49999835, 0.57      ],
#        [0.65428366, 0.66      ],
#        [0.95348   , 0.9       ],
#        [0.96024336, 0.95      ],
#        [0.74350491, 0.74      ],
#        [0.97871658, 0.96      ],
#        [0.54915759, 0.58      ]])

# %%
# plot the model to see if it fits the testing data
plt.figure(figsize = (4, 3))
plt.scatter(y_test, predictions)
plt.xlabel('Y_test')
plt.ylabel('Prediction of LinearRegression')
plt.title("Actual Data vs Model Prediction")
plt.show()

# %%
from sklearn import metrics

# %%
print('Percentage for Train Data : {}'.format(lm.score(X_train, y_train)))
print('Percentage for Test Data : {}'.format(lm.score(X_test, y_test)))
# Out:
# Percentage for Train Data : 0.8018262527866729
# Percentage for Test Data : 0.7674943370610305

# %%
print('Model is accurate because value of regression metrics is close to 0. Hence, the model created is performing well.')
print('\n')
print('1. MAE:', metrics.mean_absolute_error(predictions, y_test))
print('Absolute difference between actual and predicted values and sum all the errors and divide them by a total number of observation')
print('MAE is very less that means model is accurate and have less errors')
print('\n')
print('2. MSE:', metrics.mean_squared_error(predictions, y_test))
print('Squared distance between actual and predicted values and divide them by a total number of observation')
print('\n')
print('3. RMSE:', np.sqrt(metrics.mean_squared_error(predictions, y_test)))
print('Square root of mean squared error')
print('RMSE value is as low as 0.06 and therefore the model is better with its predictions')
# Out:
# Model is accurate because value of regression metrics is close to 0. Hence, the model created is performing well.
#
#
# 1. MAE: 0.04669186124632681
# Absolute difference between actual and predicted values and sum all the errors and divide them by a total number of observation
# MAE is very less that means model is accurate and have less errors
#
#
# 2. MSE: 0.004468290197460132
# Squared distance between actual and predicted values and divide them by a total number of observation
#
#
# 3. RMSE: 0.06684527056912952
# Square root of mean squared error
# RMSE value is as low as 0.06 and therefore thee model is better with its predictions

# %%
print('1. MAE:', metrics.mean_absolute_error(predictions, y_test))
print('2. MSE:', metrics.mean_squared_error(predictions, y_test))
print('3. RMSE:', np.sqrt(metrics.mean_squared_error(predictions, y_test)))
# Out:
# 1. MAE: 0.04669186124632681
# 2. MSE: 0.004468290197460132
# 3. RMSE: 0.06684527056912952
